# %%
import numpy as np
import matplotlib.pyplot as plt
 
plt.figure(figsize=(25,12))
plt.rcParams.update({'font.size': 15})
# set width of bar
barWidth = 0.4

plt.title("Write",fontweight='bold',fontSize=40)
#our prg
bars1 = [344.82,357.143,416.66,344.828,400,416.66,357.143,416.667,416.667,384,437.793,431.226,399.674,422.641,427.096,418.421,418.576,429.652,400,416.667,416.667]


#iozone
bars2 = [346,367,409,342.25,397.501,416.157,349.86,416.36,490.78,371.87,422.56,440.65,391.24,417.34,480.09,406.34,440.89,470.56,411.206,416.405,386.39]

 
# Set position of bar on X axis
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]

 
# Make the plot
plt.bar(r1, bars1,  width=barWidth, edgecolor='white', label='MyDisk BenchMark')
plt.bar(r2, bars2,  width=barWidth, edgecolor='white', label='Iozone')


plt.tick_params(axis='x', labelsize=15)
# Add xticks on the middle of the group bars
plt.xlabel('Record  Size and Thhreads ', fontweight='bold')
plt.ylabel('MB/Sec', fontweight='bold')
plt.xticks([r + (barWidth/2)  for r in range(len(bars1))], ['64KB 1','1MB 1','16MB 1','64KB 2','1MB 2','16MB 2','64KB 4','1MB 4','16MB 4','64KB 8','1MB 8','16MB 8','64KB 12','1MB 12','16MB 12','64KB 24','1MB 24','16MB 24','64KB 48','1MB 48','16MB 48'], rotation=90)
 
# Create legend & Show graphic
plt.legend()
plt.show()
